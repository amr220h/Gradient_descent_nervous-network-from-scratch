# %%
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard # type: ignore
import tensorflow as tf
from tensorflow import keras

# %%
df =pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %% [markdown]
# ## use tensor flow and keras

# %%
from sklearn.model_selection import train_test_split
X = df.drop('bought_insurance', axis=1)
y = df['bought_insurance']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
x_train_scaled= X_train.copy()
x_train_scaled['age'] = x_train_scaled['age'] / 100
x_test_scaled = X_test.copy() 
x_test_scaled['age'] = x_test_scaled['age'] / 100

# %%
model = keras.Sequential([keras.layers.Dense(1,input_shape=(2,),activation='sigmoid',kernel_initializer='ones',bias_initializer='zeros')])
# Out:
# c:\Users\Amr Khaled\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train_scaled, y_train, epochs=500, verbose=1, callbacks=[tensorboard_callback]) # type: ignore
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step - accuracy: 0.5263 - loss: 0.6518
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5263 - loss: 0.6515
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5263 - loss: 0.6513
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5263 - loss: 0.6510
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5263 - loss: 0.6507
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5263 - loss: 0.6504
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5263 - loss: 0.6502
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5263 - loss: 0.6499
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5263 - loss: 0.6496
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5263 - loss: 0.6494
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5263 - loss: 0.6491
# Epoch 12/500
# ...

# %%
model.evaluate(x_test_scaled, y_test) # type: ignore
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.4444 - loss: 0.6679
# [0.6678798198699951, 0.4444444477558136]

# %%
coef,intercept = model.get_weights()
print('weights:', coef)
print('intercept:', intercept)
# Out:
# weights: [[1.4589982]
#  [0.5725685]]
# intercept: [-0.5305372]
